# %%
import numpy as np
import pandas as pd

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-945de52e-7eb9-4900-9f86-51df1d0f6b31" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-945de52e-7eb9-4900-9f86-51df1d0f6b31">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df=pd.read_csv("crossfit Athletes.csv")
df
# Out:
#       competitorId        competitorName firstName        lastName gender  \
# 0           469656         Jeffrey Adler   Jeffrey           Adler      M
# 1            34796         Scott Panchik     Scott         Panchik      M
# 2           105875           Travis Mead    Travis            Mead      M
# 3           310970         Saxon Panchik     Saxon         Panchik      M
# 4            11435   Richard Froning Jr.   Richard     Froning Jr.      M
# ...            ...                   ...       ...             ...    ...
# 9911        261081            Aaron Chan     Aaron            Chan      M
# 9912        701115     Da Costa Emmanuel  Da Costa        Emmanuel      M
# 9913       1319112        Frederic Burel  Frederic           Burel      M
# 9914        747511  David Sanchez Maroto     David  Sanchez Maroto      M
# 9915          4903         Matthew Young   Matthew           Young      M
#
#      countryOfOriginName     regionName  affiliateId            affiliateName  \
# ...

# %%
df1=df.sample(5000,random_state=0)
df1
# Out:
#       competitorId      competitorName firstName   lastName gender  \
# 8085        386661  Christof Gutberlet  Christof  Gutberlet      M
# 4252        122893       Kevin Lamovec     Kevin    Lamovec      M
# 8912        438638     William Russell   William    Russell      M
# 8571       2002645          Mark Green      Mark      Green      M
# 8644        712990      Philipp Dobias   Philipp     Dobias      M
# ...            ...                 ...       ...        ...    ...
# 4114        988927       Kyle Kazarian      Kyle   Kazarian      M
# 5030        927656         Danilo Bovo    Danilo       Bovo      M
# 6199        170387         Steven Lund    Steven       Lund      M
# 8234        902663      Cameron Single   Cameron     Single      M
# 4884        690673      Raphael Winter   Raphael     Winter      M
#
#      countryOfOriginName     regionName  affiliateId  \
# 8085             Germany         Europe      24081.0
# ...

# %%
df1.fillna("NA",axis=0,inplace=True)
df1
# Out:
#       competitorId      competitorName firstName   lastName gender  \
# 8085        386661  Christof Gutberlet  Christof  Gutberlet      M
# 4252        122893       Kevin Lamovec     Kevin    Lamovec      M
# 8912        438638     William Russell   William    Russell      M
# 8571       2002645          Mark Green      Mark      Green      M
# 8644        712990      Philipp Dobias   Philipp     Dobias      M
# ...            ...                 ...       ...        ...    ...
# 4114        988927       Kyle Kazarian      Kyle   Kazarian      M
# 5030        927656         Danilo Bovo    Danilo       Bovo      M
# 6199        170387         Steven Lund    Steven       Lund      M
# 8234        902663      Cameron Single   Cameron     Single      M
# 4884        690673      Raphael Winter   Raphael     Winter      M
#
#      countryOfOriginName     regionName affiliateId  \
# 8085             Germany         Europe     24081.0
# 4252       United States  North America      7094.0
# ...

# %%
df1
# Out:
#       competitorId      competitorName firstName   lastName gender  \
# 8085        386661  Christof Gutberlet  Christof  Gutberlet      M
# 4252        122893       Kevin Lamovec     Kevin    Lamovec      M
# 8912        438638     William Russell   William    Russell      M
# 8571       2002645          Mark Green      Mark      Green      M
# 8644        712990      Philipp Dobias   Philipp     Dobias      M
# ...            ...                 ...       ...        ...    ...
# 4114        988927       Kyle Kazarian      Kyle   Kazarian      M
# 5030        927656         Danilo Bovo    Danilo       Bovo      M
# 6199        170387         Steven Lund    Steven       Lund      M
# 8234        902663      Cameron Single   Cameron     Single      M
# 4884        690673      Raphael Winter   Raphael     Winter      M
#
#      countryOfOriginName     regionName affiliateId  \
# 8085             Germany         Europe     24081.0
# 4252       United States  North America      7094.0
# ...

# %%
import seaborn as sns

# %%
sns.pairplot(df1,hue='overallRank')

# %%
sns.histplot(data=df1,x='height_cm',color="blue",bins=10)
# Out:
# <Axes: xlabel='height_cm', ylabel='Count'>

# %%
sns.histplot(x="height_cm",y="overallScore",data=df1,color='purple')
plt.title('overallscore by height_cm')
# Out:
# Text(0.5, 1.0, 'overallscore by height_cm')

# %%
sns.histplot(x="height_cm",y="overallRank",data=df1,color='purple')
plt.title('overallrank by height_cm')
# Out:
# Text(0.5, 1.0, 'overallrank by height_cm')

# %%
sns.barplot(x='regionName',y='overallRank',data=df1)#by region name overall rank
plt.title('overallrank by regionName')
# Out:
# Text(0.5, 1.0, 'overallrank by regionName')

# %%
sns.barplot(x='regionName',y='overallScore',data=df1)#by region overall score
plt.title('overallscore by regionName')
# Out:
# Text(0.5, 1.0, 'overallscore by regionName')

# %%
sns.histplot(data=df1,x='age',color="yellow",bins=10)
plt.title('count of age')
# Out:
# Text(0.5, 1.0, 'count of age')

# %%
sns.histplot(x="age",y="overallScore",data=df1,color='yellow',bins=10)
plt.title('overallscore by age')
# Out:
# Text(0.5, 1.0, 'overallscore by age')

# %%
sns.histplot(x="age",y="overallRank",data=df1,color='yellow',bins=10)
plt.title('overallrank by age')
# Out:
# Text(0.5, 1.0, 'overallrank by age')

# %%
sns.countplot(x='gender',data=df1)
plt.title('count of gender')
# Out:
# Text(0.5, 1.0, 'count of gender')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
columns_to_correlate = ['competitorId', 'weight_kg', 'height_cm', 'overallRank', 'overallScore', 'affiliateId','affiliateName','year']
correlation_matrix = df[columns_to_correlate].corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0)
plt.title('Correlation Heatmap')
plt.show()
# Out:
# <ipython-input-134-b6803bca77d3>:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df[columns_to_correlate].corr()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
plt.figure(figsize=(5, 5))
sns.barplot(x='regionName', y='height_cm', data=df1)
median = np.median(df1['height_cm'])
plt.axhline(median, color='black', linestyle='--', label='Median Height')
plt.legend()
plt.title('Average Height by Region')
plt.xlabel('Region')
plt.ylabel('Average Height (cm)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
