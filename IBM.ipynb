# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-36899f52-d392-4d2e-b07d-a92393b189d1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-36899f52-d392-4d2e-b07d-a92393b189d1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("ibm.csv")
df
# Out:
#     Age Attrition     BusinessTravel  DailyRate              Department  \
# 0    41       Yes      Travel_Rarely       1102                   Sales
# 1    49        No  Travel_Frequently        279  Research & Development
# 2    37       Yes      Travel_Rarely       1373  Research & Development
# 3    33        No  Travel_Frequently       1392  Research & Development
# 4    27        No      Travel_Rarely        591  Research & Development
# ..  ...       ...                ...        ...                     ...
# 94   32        No      Travel_Rarely       1093                   Sales
# 95   54        No      Travel_Rarely       1217  Research & Development
# 96   24        No      Travel_Rarely       1353                   Sales
# 97   28        No         Non-Travel        120                   Sales
# 98   58        No      Travel_Rarely        682                   Sales
#
#     DistanceFromHome  Education    EducationField  EmployeeCount  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       99 non-null     int64
#  1   Attrition                 99 non-null     object
#  2   BusinessTravel            99 non-null     object
#  3   DailyRate                 99 non-null     int64
#  4   Department                99 non-null     object
#  5   DistanceFromHome          99 non-null     int64
#  6   Education                 99 non-null     int64
#  7   EducationField            99 non-null     object
#  8   EmployeeCount             99 non-null     int64
#  9   EmployeeNumber            99 non-null     int64
#  10  EnvironmentSatisfaction   99 non-null     int64
#  11  Gender                    99 non-null     object
#  12  HourlyRate                99 non-null     int64
#  13  JobInvolvement            99 non-null     int64
# ...

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.tail()
# Out:
#     Age Attrition BusinessTravel  DailyRate              Department  \
# 94   32        No  Travel_Rarely       1093                   Sales
# 95   54        No  Travel_Rarely       1217  Research & Development
# 96   24        No  Travel_Rarely       1353                   Sales
# 97   28        No     Non-Travel        120                   Sales
# 98   58        No  Travel_Rarely        682                   Sales
#
#     DistanceFromHome  Education    EducationField  EmployeeCount  \
# 94                 6          4           Medical              1
# 95                 2          4  Technical Degree              1
# 96                 3          2             Other              1
# 97                 4          3           Medical              1
# 98                10          4           Medical              1
#
#     EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# 94             125  ...                         1            80
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.drop_duplicates()
# Out:
#     Age Attrition     BusinessTravel  DailyRate              Department  \
# 0    41       Yes      Travel_Rarely       1102                   Sales
# 1    49        No  Travel_Frequently        279  Research & Development
# 2    37       Yes      Travel_Rarely       1373  Research & Development
# 3    33        No  Travel_Frequently       1392  Research & Development
# 4    27        No      Travel_Rarely        591  Research & Development
# ..  ...       ...                ...        ...                     ...
# 94   32        No      Travel_Rarely       1093                   Sales
# 95   54        No      Travel_Rarely       1217  Research & Development
# 96   24        No      Travel_Rarely       1353                   Sales
# 97   28        No         Non-Travel        120                   Sales
# 98   58        No      Travel_Rarely        682                   Sales
#
#     DistanceFromHome  Education    EducationField  EmployeeCount  \
# ...

# %%
import seaborn as sns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       99 non-null     int64
#  1   Attrition                 99 non-null     object
#  2   BusinessTravel            99 non-null     object
#  3   DailyRate                 99 non-null     int64
#  4   Department                99 non-null     object
#  5   DistanceFromHome          99 non-null     int64
#  6   Education                 99 non-null     int64
#  7   EducationField            99 non-null     object
#  8   EmployeeCount             99 non-null     int64
#  9   EmployeeNumber            99 non-null     int64
#  10  EnvironmentSatisfaction   99 non-null     int64
#  11  Gender                    99 non-null     object
#  12  HourlyRate                99 non-null     int64
#  13  JobInvolvement            99 non-null     int64
# ...

# %%
x=df[df['OverTime']=='Yes']#Find out the employee number and dept of employee who does overtime?
y=x[['EmployeeNumber','Department']]
print(y)
# Out:
#     EmployeeNumber              Department
# 0                1                   Sales
# 2                4  Research & Development
# 3                5  Research & Development
# 6               10  Research & Development
# 11              15  Research & Development
# 14              19  Research & Development
# 16              21  Research & Development
# 17              22  Research & Development
# 19              24  Research & Development
# 26              33  Research & Development
# 31              40  Research & Development
# 34              45  Research & Development
# 36              47                   Sales
# 38              51  Research & Development
# 48              62                   Sales
# 50              64  Research & Development
# 51              65  Research & Development
# 52              68                   Sales
# 53              70  Research & Development
# 54              72                   Sales
# 55              73  Research & Development
# ...

# %%
sorted=df.sort_values('YearsSinceLastPromotion',ascending=False)#Find out last 5 employees based on last promotion received?
last_5_emp=sorted.tail(5)
last_5_emp
# Out:
#     Age Attrition     BusinessTravel  DailyRate              Department  \
# 54   26        No      Travel_Rarely       1443                   Sales
# 59   37        No      Travel_Rarely       1115  Research & Development
# 65   55        No      Travel_Rarely        836  Research & Development
# 66   36        No  Travel_Frequently       1195  Research & Development
# 49   35        No      Travel_Rarely       1229  Research & Development
#
#     DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 54                23          3      Marketing              1              72
# 59                 1          4  Life Sciences              1              77
# 65                 8          3        Medical              1              84
# 66                11          3  Life Sciences              1              85
# 49                 8          1  Life Sciences              1              63
#
# ...

# %%
avg_income= df.groupby('Department')['MonthlyIncome'].mean() #3
emp_avg_income=df[df['MonthlyIncome']>df['Department'].map(avg_income)]
x=emp_avg_income[['EmployeeNumber','Department','MonthlyIncome']].values.tolist()
x
# Out:
# [[12, 'Research & Development', 9526],
#  [20, 'Research & Development', 9980],
#  [23, 'Sales', 15427],
#  [28, 'Research & Development', 11994],
#  [32, 'Research & Development', 19094],
#  [35, 'Sales', 6825],
#  [36, 'Research & Development', 10248],
#  [38, 'Sales', 18947],
#  [40, 'Research & Development', 6465],
#  [56, 'Sales', 8726],
#  [58, 'Research & Development', 19545],
#  [70, 'Research & Development', 9884],
#  [73, 'Research & Development', 13458],
#  [74, 'Sales', 9069],
#  [76, 'Research & Development', 5915],
#  [77, 'Research & Development', 5993],
#  [78, 'Research & Development', 6162],
#  [80, 'Research & Development', 18740],
#  [81, 'Sales', 7637],
#  [83, 'Research & Development', 10096],
#  [84, 'Research & Development', 14756],
#  [85, 'Research & Development', 6499],
#  [86, 'Research & Development', 9724],
#  [96, 'Research & Development', 6220],
#  [101, 'Research & Development', 13245],
#  [102, 'Research & Development', 13664],
# ...

# %%
x = df['MonthlyIncome'].idxmax() # IBM question:1
df.loc[x][['EmployeeNumber','MonthlyIncome']]
# Out:
# EmployeeNumber       58
# MonthlyIncome     19545
# Name: 45, dtype: object

# %%
import matplotlib.pyplot as plt
sns.scatterplot(x='Gender',y='MonthlyIncome',data=df)#2
plt.title('Gender vs MontlyIncome')
# Out:
# Text(0.5, 1.0, 'Gender vs MontlyIncome')

# %%
R_c_count=df[df['JobRole']=='Research Scientist'].shape[0]#4
S_c_count=df[df['JobRole']=='Sales Executive'].shape[0]
print("Number of employess  worked as Research Scientist:",R_c_count)
print("Number of employess  worked as sales Executive:",S_c_count)
# Out:
# Number of employess  worked as Research Scientist: 20
# Number of employess  worked as sales Executive: 20

# %%
sorted=df.sort_values('MaritalStatus')# 5 To find the employee marital status as ascending to descending order
print(sorted['MaritalStatus'])
# Out:
# 35    Divorced
# 52    Divorced
# 79    Divorced
# 20    Divorced
# 17    Divorced
#         ...
# 55      Single
# 61      Single
# 63      Single
# 30      Single
# 98      Single
# Name: MaritalStatus, Length: 99, dtype: object

# %%
x=df[df['EducationField']=='Medical']#6
x
# Out:
#     Age Attrition     BusinessTravel  DailyRate              Department  \
# 4    27        No      Travel_Rarely        591  Research & Development
# 6    59        No      Travel_Rarely       1324  Research & Development
# 9    36        No      Travel_Rarely       1299  Research & Development
# 10   35        No      Travel_Rarely        809  Research & Development
# 13   34        No      Travel_Rarely       1346  Research & Development
# 17   22        No         Non-Travel       1123  Research & Development
# 24   34       Yes      Travel_Rarely        699  Research & Development
# 28   44        No      Travel_Rarely        477  Research & Development
# 30   33        No      Travel_Rarely        924  Research & Development
# 32   30        No      Travel_Rarely        125  Research & Development
# 34   24       Yes      Travel_Rarely        813  Research & Development
# 35   43        No      Travel_Rarely       1273  Research & Development
# ...

# %%
satisfied=df[df['EnvironmentSatisfaction']>=4].shape[0]#7
print("satisfied employess are:",satisfied)
# Out:
# satisfied employess are: 25

# %%
avg_income=df['MonthlyIncome'].mean()#8
x=df[df['MonthlyIncome']>avg_income]
x
# Out:
#     Age Attrition     BusinessTravel  DailyRate              Department  \
# 8    38        No  Travel_Frequently        216  Research & Development
# 15   29        No      Travel_Rarely       1389  Research & Development
# 18   53        No      Travel_Rarely       1219                   Sales
# 22   34        No      Travel_Rarely        419  Research & Development
# 25   53        No      Travel_Rarely       1282  Research & Development
# 27   42        No      Travel_Rarely        691                   Sales
# 28   44        No      Travel_Rarely        477  Research & Development
# 29   46        No      Travel_Rarely        705                   Sales
# 31   44        No      Travel_Rarely       1459  Research & Development
# 43   27        No  Travel_Frequently        994                   Sales
# 45   41       Yes      Travel_Rarely       1360  Research & Development
# 53   35        No         Non-Travel       1097  Research & Development
# ...

# %%
age=df[df['Age']>35]#9
print(age['Age'])
# Out:
# 0     41
# 1     49
# 2     37
# 6     59
# 8     38
# 9     36
# 18    53
# 19    38
# 21    36
# 25    53
# 27    42
# 28    44
# 29    46
# 31    44
# 33    39
# 35    43
# 36    50
# 38    36
# 45    41
# 47    37
# 48    46
# 50    48
# 52    44
# 59    37
# 61    38
# 62    50
# 63    59
# 64    36
# 65    55
# 66    36
# 67    45
# 69    36
# 70    59
# 74    36
# 77    45
# 78    37
# 79    46
# 82    55
# 83    38
# 85    56
# 87    51
# 89    46
# 90    40
# 91    51
# 93    46
# 95    54
# 98    58
# Name: Age, dtype: int64

# %%
frequently_travel=df[df['BusinessTravel']=='Travel_Frequently'].shape[0]#10
frequently_travel
# Out:
# 17

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.hist(df['Age'],bins=20,edgecolor='black')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age Distribution')
plt.subplot(1,2,2)
plt.hist(df['MonthlyIncome'],bins=20,edgecolor='black')
plt.xlabel('MonthlyIncome')
plt.ylabel('Frequency')
plt.title('MonthlyIncome Distribution')
plt.tight_layout()
plt.show()

# %%
sns.boxplot(x='EducationField',y='MonthlyIncome',data=df)#12
# Out:
# <Axes: xlabel='EducationField', ylabel='MonthlyIncome'>

# %%
current_manager=df[['EmployeeNumber','YearsWithCurrManager']]#13
current_manager
# Out:
#     EmployeeNumber  YearsWithCurrManager
# 0                1                     5
# 1                2                     7
# 2                4                     0
# 3                5                     0
# 4                7                     2
# ..             ...                   ...
# 94             125                     7
# 95             126                     3
# 96             128                     2
# 97             129                     4
# 98             131                     8
#
# [99 rows x 2 columns]

# %%
employee_leaving= df[df['Attrition']=='Yes'].shape[0]#14
print("Number of enmployees leaving the company",employee_leaving)
# Out:
# Number of enmployees leaving the company 15
