# %%
from google.colab import files# import data
uploaded= files.upload()
# Out:
#      <input type="file" id="files-7a35e94a-b346-4f65-ab13-3a5ca4814931" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7a35e94a-b346-4f65-ab13-3a5ca4814931">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy as np# reading data anmd removing  duplicate header
import pandas as pd
df=pd.read_csv("Newyork.csv",header=1)
df
# Out:
#                                           FacilityName  \
# 0                                   Engine 4/Ladder 15
# 1                                  Engine 10/Ladder 10
# 2                                             Engine 6
# 3    Engine 7/Ladder 1/Battalion 1/Manhattan Boroug...
# 4                                             Ladder 8
# ..                                                 ...
# 213                  Engine 162/Ladder 82/Battalion 23
# 214                               Engine 167/Ladder 87
# 215                               Engine 164/Ladder 84
# 216                          Engine 168/EMS Station 23
# 217                               Engine 151/Ladder 76
#
#               FacilityAddress        Borough
# 0             42 South Street      Manhattan
# 1          124 Liberty Street      Manhattan
# 2           49 Beekman Street      Manhattan
# 3        100-104 Duane Street      Manhattan
# 4       14 North Moore Street      Manhattan
# ...

# %%
df.head()#first 5 rows
# Out:
#                                         FacilityName        FacilityAddress  \
# 0                                 Engine 4/Ladder 15        42 South Street
# 1                                Engine 10/Ladder 10     124 Liberty Street
# 2                                           Engine 6      49 Beekman Street
# 3  Engine 7/Ladder 1/Battalion 1/Manhattan Boroug...   100-104 Duane Street
# 4                                           Ladder 8  14 North Moore Street
#
#      Borough
# 0  Manhattan
# 1  Manhattan
# 2  Manhattan
# 3  Manhattan
# 4  Manhattan

# %%
df.info()# using info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 218 entries, 0 to 217
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   FacilityName     218 non-null    object
#  1   FacilityAddress  218 non-null    object
#  2   Borough          218 non-null    object
# dtypes: object(3)
# memory usage: 5.2+ KB

# %%
df.describe()# statistical data
# Out:
#               FacilityName  FacilityAddress   Borough
# count                  218              218       218
# unique                 218              218         5
# top     Engine 4/Ladder 15  42 South Street  Brooklyn
# freq                     1                1        66

# %%
x=list(df.columns.values)# columns names
x
# Out:
# ['FacilityName', 'FacilityAddress', 'Borough']

# %%
df.index# index of the data
# Out:
# RangeIndex(start=0, stop=218, step=1)

# %%
df.count()# cont of attributes
# Out:
# FacilityName       218
# FacilityAddress    218
# Borough            218
# dtype: int64

# %%
df.dtypes# data types
# Out:
# FacilityName       object
# FacilityAddress    object
# Borough            object
# dtype: object

# %%
df = pd.read_csv("Newyork.csv", index_col ="Borough",header=1)#select fdny info borough wise
df
# Out:
#                                                     FacilityName  \
# Borough
# Manhattan                                     Engine 4/Ladder 15
# Manhattan                                    Engine 10/Ladder 10
# Manhattan                                               Engine 6
# Manhattan      Engine 7/Ladder 1/Battalion 1/Manhattan Boroug...
# Manhattan                                               Ladder 8
# ...                                                          ...
# Staten Island                  Engine 162/Ladder 82/Battalion 23
# Staten Island                               Engine 167/Ladder 87
# Staten Island                               Engine 164/Ladder 84
# Staten Island                          Engine 168/EMS Station 23
# Staten Island                               Engine 151/Ladder 76
#
#                         FacilityAddress
# Borough
# Manhattan               42 South Street
# Manhattan            124 Liberty Street
# Manhattan             49 Beekman Street
# ...

# %%
df=pd.read_csv("Newyork.csv")#View fdny info for each borough
x=df.groupby('Borough').count()
x
# Out:
#                FacilityName  FacilityAddress
# Borough
# Borough                   1                1
# Bronx                    34               34
# Brooklyn                 66               66
# Manhattan                48               48
# Queens                   50               50
# Staten Island            20               20

# %%
count_manhattan=df[df['Borough']=='Manhattan']#select fdny for manhattan
count_manhattan
# Out:
#                                          FacilityName  \
# 1                                  Engine 4/Ladder 15
# 2                                 Engine 10/Ladder 10
# 3                                            Engine 6
# 4   Engine 7/Ladder 1/Battalion 1/Manhattan Boroug...
# 5                                            Ladder 8
# 6                                   Engine 9/Ladder 6
# 7                     Engine 15/Ladder 18/Battalion 4
# 8                                 Engine 28/Ladder 11
# 9                                            Engine 5
# 10                                          Engine 55
# 11                               Ladder 20/Division 1
# 12                     Engine 24/Ladder 5/Battalion 2
# 13                                 Engine 33/Ladder 9
# 14                               Ladder 3/Battalion 6
# 15                                           Squad 18
# 16                                Engine 34/Ladder 21
# ...
